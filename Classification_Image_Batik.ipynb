# %% [markdown]
# <a href="https://colab.research.google.com/github/noviambar/AdminLTE3/blob/master/Classification_Image_Batik.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import zipfile, os
local_zip = '/content/drive/My Drive/Dataset.zip'
zip_ref = zipfile.ZipFile(local_zip, 'r')
zip_ref.extractall()
zip_ref.close()

# %%
print("Train Data each class")
print('Batik Kawung    :', len(os.listdir('/content/Dataset/Batik Kawung/')))
print('Batik Lasem  :', len(os.listdir('/content/Dataset/Batik Lasem')))
print('Batik Lasem Motif Burung Hong  :', len(os.listdir('/content/Dataset/Batik Lasem Motif Burung Hong')))
print('Batik Lasem Motif Gunung Ringgit  :', len(os.listdir('/content/Dataset/Batik Lasem Motif Gunung Ringgit')))
print('Batik Lasem Motif Naga :', len(os.listdir('/content/Dataset/Batik Lasem Motif Naga')))
print('Batik Lasem Motif Watu Pecah   :', len(os.listdir('/content/Dataset/Batik Lasem Motif Watu Pecah')))
print('Batik Megamendung :', len(os.listdir('/content/Dataset/Batik Megamendung')))
print('Batik Parang   :', len(os.listdir('/content/Dataset/Batik Parang')))
# Out:
# Train Data each class
# Batik Kawung    : 691
# Batik Lasem  : 50
# Batik Lasem Motif Burung Hong  : 28
# Batik Lasem Motif Gunung Ringgit  : 22
# Batik Lasem Motif Naga : 40
# Batik Lasem Motif Watu Pecah   : 13
# Batik Megamendung : 160
# Batik Parang   : 1720

# %%
os.mkdir('/content/Dataset/tmp/s/')
os.mkdir('/content/Dataset/tmp/s/train/')
os.mkdir('/content/Dataset/tmp/s/val/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Kawung/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Kawung/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Lasem/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Lasem/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Lasem Motif Burung Hong/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Lasem Motif Burung Hong/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Lasem Motif Gunung Ringgit/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Lasem Motif Gunung Ringgit/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Lasem Motif Naga/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Lasem Motif Naga/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Lasem Motif Watu Pecah/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Lasem Motif Watu Pecah/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Megamendung/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Megamendung/')
os.mkdir('/content/Dataset/tmp/s/train/Batik Parang/')
os.mkdir('/content/Dataset/tmp/s/val/Batik Parang/')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-10-ff089d9e01d6> in <module>()
# ----> 1 os.mkdir('/content/Dataset/tmp/s/')
#       2 os.mkdir('/content/Dataset/tmp/s/train/')
#       3 os.mkdir('/content/Dataset/tmp/s/val/')
#       4 os.mkdir('/content/Dataset/tmp/s/train/Batik Kawung/')
#       5 os.mkdir('/content/Dataset/tmp/s/val/Batik Kawung/')
#
# FileExistsError: [Errno 17] File exists: '/content/Dataset/tmp/s/'

# %%
import random
from shutil import copyfile

def train_val_split(source, train, val, train_ratio):
  total_size = len(os.listdir(source))
  train_size = int(train_ratio * total_size)
  val_size = total_size - train_size

  randomized = random.sample(os.listdir(source), total_size)
  train_files = randomized[0:train_size]
  val_files = randomized[train_size:total_size]

  for i in train_files:
    i_file = source + i
    destination = train + i
    copyfile(i_file, destination)

  for i in val_files:
    i_file = source + i
    destination = val + i
    copyfile(i_file, destination)

train_ratio = 0.8

# %%
#Pembagian Training dan Validasi

source_00 = '/content/Dataset/Batik Kawung/'
train_00 = '/content/Dataset/tmp/s/train/Batik Kawung/'
val_00 = '/content/Dataset/tmp/s/val/Batik Kawung/'
train_val_split(source_00, train_00, val_00, train_ratio)

source_01 = '/content/Dataset/Batik Lasem/'
train_01 = '/content/Dataset/tmp/s/train/Batik Lasem/'
val_01 = '/content/Dataset/tmp/s/val/Batik Lasem/'
train_val_split(source_01, train_01, val_01, train_ratio)

source_02 = '/content/Dataset/Batik Lasem Motif Burung Hong/'
train_02 = '/content/Dataset/tmp/s/train/Batik Lasem Motif Burung Hong/'
val_02 = '/content/Dataset/tmp/s/val/Batik Lasem Motif Burung Hong/'
train_val_split(source_02, train_02, val_02, train_ratio)

source_03 = '/content/Dataset/Batik Lasem Motif Gunung Ringgit/'
train_03 = '/content/Dataset/tmp/s/train/Batik Lasem Motif Gunung Ringgit/'
val_03 = '/content/Dataset/tmp/s/val/Batik Lasem Motif Gunung Ringgit/'
train_val_split(source_03, train_03, val_03, train_ratio)

source_04 = '/content/Dataset/Batik Lasem Motif Naga/'
train_04 = '/content/Dataset/tmp/s/train/Batik Lasem Motif Naga/'
val_04 = '/content/Dataset/tmp/s/val/Batik Lasem Motif Naga/'
train_val_split(source_04, train_04, val_04, train_ratio)

source_05 = '/content/Dataset/Batik Lasem Motif Watu Pecah/'
train_05 = '/content/Dataset/tmp/s/train/Batik Lasem Motif Watu Pecah/'
val_05 = '/content/Dataset/tmp/s/val/Batik Lasem Motif Watu Pecah/'
train_val_split(source_05, train_05, val_05, train_ratio)

source_06 = '/content/Dataset/Batik Megamendung/'
train_06 = '/content/Dataset/tmp/s/train/Batik Megamendung/'
val_06 = '/content/Dataset/tmp/s/val/Batik Megamendung/'
train_val_split(source_06, train_06, val_06, train_ratio)

source_07 = '/content/Dataset/Batik Parang/'
train_07 = '/content/Dataset/tmp/s/train/Batik Parang/'
val_07 = '/content/Dataset/tmp/s/val/Batik Parang/'
train_val_split(source_07, train_07, val_07, train_ratio)

# %%
print('Data Batik Kawung: ',len(os.listdir('/content/Dataset/tmp/s/train/Batik Kawung')))
print('Data Train Batik Kawung: ',len(os.listdir('/content/Dataset/tmp/s/train/Batik Kawung/')))
print('Data Validation Batik Kawung: ',len(os.listdir('/content/Dataset/tmp/s/val/Batik Kawung/')))
# Out:
# Data Batik Kawung:  668
# Data Train Batik Kawung:  668
# Data Validation Batik Kawung:  255

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(
                  rescale = 1./255.,
                  rotation_range = 30,
                  horizontal_flip = True,
                  shear_range = 0.3,
                  fill_mode = 'nearest',
                  width_shift_range = 0.2,
                  height_shift_range = 0.2,
                  zoom_range = 0.1
)

val_datagen = ImageDataGenerator(
                rescale = 1./255.,
                rotation_range = 30,
                horizontal_flip = True,
                shear_range = 0.3,
                fill_mode = 'nearest',
                width_shift_range = 0.2,
                height_shift_range = 0.2,
                zoom_range = 0.1
)

# %%
train_dir = '/content/Dataset/tmp/s/train'
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size = (250, 250),
    batch_size = 32,
    class_mode = 'categorical'
)

val_dir = '/content/Dataset/tmp/s/val'
val_generator = val_datagen.flow_from_directory(
    val_dir,
    target_size = (250, 250),
    batch_size = 32,
    class_mode = 'categorical'
)
# Out:
# Found 2624 images belonging to 8 classes.
# Found 994 images belonging to 8 classes.

# %%
# callbacks
class myCallback(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs = {}):
    if(logs.get('accuracy') > 0.99):
      print('\nAkurasi mencapai 99%')
      self.model.stop_training = True

callbacks = myCallback()

# %%
import tensorflow as tf

model = tf.keras.models.Sequential([
          tf.keras.layers.Conv2D(32, (3, 3), activation = 'relu', input_shape = (250, 250, 3)),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Conv2D(64, (3, 3), activation = 'relu'),
          tf.keras.layers.MaxPooling2D(2, 2),
          tf.keras.layers.Flatten(),
          tf.keras.layers.Dense(200, activation = 'relu'),
          tf.keras.layers.Dropout(0.3,seed=112),
          tf.keras.layers.Dense(500, activation = 'relu'),
          tf.keras.layers.Dropout(0.5,seed=112),
          tf.keras.layers.Dense(8, activation = 'softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_3 (Conv2D)            (None, 248, 248, 32)      896
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 124, 124, 32)      0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 122, 122, 64)      18496
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 61, 61, 64)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 59, 59, 64)        36928
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 29, 29, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 53824)             0
# ...

# %%
model.compile(loss='categorical_crossentropy',
              optimizer='Adam',
              metrics=['accuracy'])

# %%
import sys
from PIL import Image
sys.modules['Image'] = Image

from PIL import Image
print(Image.__file__)

import Image
print(Image.__file__)
# Out:
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py
# /usr/local/lib/python3.7/dist-packages/PIL/Image.py

# %%
history = model.fit(
            train_generator,
            steps_per_epoch = 10,
            epochs = 30,
            validation_data = val_generator,
            validation_steps = 5,
            verbose = 1,
            callbacks = [callbacks]
)
# Out:
# Epoch 1/30
# 10/10 [==============================] - 47s 5s/step - loss: 1.4818 - accuracy: 0.5031 - val_loss: 1.0433 - val_accuracy: 0.6750
# Epoch 2/30
# 10/10 [==============================] - 44s 4s/step - loss: 1.1491 - accuracy: 0.5625 - val_loss: 0.8552 - val_accuracy: 0.6938
# Epoch 3/30
# 10/10 [==============================] - 44s 4s/step - loss: 0.9652 - accuracy: 0.5938 - val_loss: 0.9581 - val_accuracy: 0.6187
# Epoch 4/30
# 10/10 [==============================] - 44s 4s/step - loss: 0.9715 - accuracy: 0.6500 - val_loss: 0.9026 - val_accuracy: 0.6812
# Epoch 5/30
# 10/10 [==============================] - 45s 4s/step - loss: 0.9391 - accuracy: 0.6187 - val_loss: 0.9268 - val_accuracy: 0.6187
# Epoch 6/30
# 10/10 [==============================] - 44s 4s/step - loss: 1.0273 - accuracy: 0.6281 - val_loss: 0.8907 - val_accuracy: 0.8375
# Epoch 7/30
# ...

# %%
import matplotlib.image  as mpimg
import matplotlib.pyplot as plt


acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label = 'Training Accuracy')
plt.plot(epochs, val_acc, 'b', label = 'Validation Accuracy')
plt.title('Training and Validation accuracy')
plt.legend(loc = 'best')
plt.show()

plt.plot(epochs, loss, 'r', label = 'Training Loss')
plt.plot(epochs, val_loss, 'b', label = 'Validation Loss')
plt.title('Training and Validation loss')
plt.legend(loc = 'best')
plt.show()

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():

  # predicting images
  path = fn
  img = image.load_img(path, target_size = (250, 250))
  imgplot = plt.imshow(img)
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis = 0)

  images = np.vstack([x])
  classes = model.predict(images, batch_size = 200)

  print(fn)

  class_list = os.listdir('/content/Dataset')
  
  for j in range(42):
    if classes[0][j] == 1. :
      print('This image belongs to class', class_list[j])
      break
# Out:
#      <input type="file" id="files-ea20fc6e-0dec-47b8-b261-f9668506d025" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ea20fc6e-0dec-47b8-b261-f9668506d025">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Batik Parang (9).jpg to Batik Parang (9).jpg
# Batik Parang (9).jpg
# This image belongs to class Batik Lasem Motif Watu Pecah
